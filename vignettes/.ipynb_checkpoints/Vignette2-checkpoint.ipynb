# %% [markdown]
# # Load libraries

# %%
suppressPackageStartupMessages({
    library(crescendo)
    library(parallel)
})

parallelEstimation <- function(Ycounts, meta_data, R, genes_use = NULL, id_col = 'CellID', batch_col = 'batch',
                      prop = 1, min_cells = 50, constant_umi = TRUE, merge_clusters = TRUE,
                      lambda = NULL, alpha = 0, seed = 2, return_obj = FALSE, mc.cores = NULL, impute_reads = NULL){
    if(!(batch_col %in% colnames(meta_data))){
        stop('Provided column does not exist. Please input name of batch column')
    }
    if(!(id_col %in% colnames(meta_data))){
        stop('Provided column does not exist. Please input name of cell ID column')
    }
    
    if(is.null(mc.cores)){
        mc.cores <- max(1, detectCores() - 1)
    }
    meta_data$batch <- meta_data[[batch_col]]
    
    # Merge redundant clusters
    if(merge_clusters){
        R <- t(merge_redundant_clusters(R, 0.99))
        colnames(R) <- paste0('R', 1:ncol(R))
    } else{
        R <- t(R)
        colnames(R) <- paste0('R', 1:ncol(R))
    }
    
    # Use selected genes is applicable
    if(!is.null(genes_use)){
        Ycounts <- Ycounts[genes_use, , drop = FALSE]
    } else{
        genes_use <- rownames(Ycounts)
    }
    # return(Ycounts)
    Ycounts <- t(Ycounts)
    # return(Ycounts)
    
    offset <- log(meta_data$nUMI)
    if(constant_umi){
        final_reads <- log(rep(median(meta_data$nUMI), length(meta_data$nUMI)))
    } else{
        final_reads <- offset
    }
    if(!is.null(impute_reads)){
        final_reads <- impute_reads
    }
    
    message('Creating design matrix')
    design_full <- create_design_matrix(meta_data = meta_data, R = R, id_col = id_col)
    # Designate terms to keep (e.g. cluster terms)
    terms_keep <- grep('^R\\d+$|disease|(Intercept)', colnames(design_full), value = TRUE)
    # Designate terms to remove (e.g. interaction terms)
    terms_remove_crossed <- terms_remove_crossed <- grep(':batch', colnames(design_full), value = TRUE)
    
    # Downsampling
    if(prop != 1){
        message('Getting discrete Harmony cluster')
        meta_data$sampled_clus <- sample_harmony_clus(
            harmony_clusters = R,
            seed = seed,
            mc.cores = mc.cores
        )
        message('Downsampling')
        temp_meta <- downsample_batch_clus(
            meta_data = meta_data,
            id_col = id_col,
            batch_col = batch_col,
            clus_col = 'sampled_clus',
            min_cells = min_cells,
            prop = prop,
            seed = seed
        )

        temp_Ycounts <- Ycounts[temp_meta$idx, , drop = FALSE]
        temp_R <- R[temp_meta$idx, ]
        temp_offset <- offset[temp_meta$idx]
        temp_design <- design_full[temp_meta$idx, , drop = FALSE]
    } else{
        message('No downsampling selected')
        temp_meta <- meta_data
        temp_Ycounts <- Ycounts
        temp_R <- R
        temp_offset <- offset
        temp_design <- design_full
    }
    
    # Estimation
    message('Estimating')
    betas <- estimate_betas(
        Ycounts = temp_Ycounts,
        R = temp_R,
        design_full = temp_design,
        lambda = lambda,
        alpha = alpha,
        genes_use = genes_use,
        offset = temp_offset,
        mc.cores = mc.cores
    )
}

# %% [markdown]
# # Load data

# %%
# system.time({
#     obj <- readRDS(system.file("extdata", "pbmc_4gene_obj.rds", package = "crescendo"))
# })

# %%
system.time({
    obj <- readRDS('/data/srlab1/nmillard/crescendo/inst/extdata/pbmc_4gene_obj.rds')
})
# Out:
#    user  system elapsed
#   0.253   0.022   1.277

# %%
obj %>% str(1)
# Out:
# List of 3
#  $ meta_data: tibble [20,792 × 12] (S3: tbl_df/tbl/data.frame)
#  $ exprs_raw:Formal class 'dgCMatrix' [package "Matrix"] with 6 slots
#  $ R        : num [1:100, 1:20792] 9.56e-02 2.05e-09 8.28e-11 1.30e-11 3.24e-11 ...

# %% [markdown]
# # Set up parameters

# %%
# Set which genes to correct and parameters for coorrection (parameters explained in GettingStarted vignette)
genes_use <- obj$exprs_raw %>% rownames
genes_use
prop <- 0.05
min_cells <- 50

batch_col <- 'batch'
id_col = 'CellID'
constant_umi <- TRUE
merge_clusters <- TRUE

mc.cores <- NULL
# mc.cores <- 1
alpha <- 0
lambda <- NULL
# Out:
# [1] "TRAC"  "MS4A1" "CD3E"  "CD3D"

# %% [markdown]
# ## Split genes into sets of 2

# %%
genes_correct <- obj$exprs_raw %>% rownames
system.time({
    gene_lists <- split(genes_correct, ceiling(seq_along(genes_correct) / 2))
})
gene_lists
# Out:
#    user  system elapsed
#   0.001   0.000   0.000
# $`1`
# [1] "TRAC"  "MS4A1"
#
# $`2`
# [1] "CD3E" "CD3D"

# %% [markdown]
# # Perform downsampling and estimation

# %%
system.time({
    betas <- mclapply(gene_lists, function(x){
        parallelEstimation(
            Ycounts = obj$exprs_raw,
            meta_data = obj$meta_data,
            R = obj$R,
            genes_use = x,
            prop = prop,
            min_cells = min_cells,
            batch_col = batch_col,
            id_col = id_col,
            constant_umi = TRUE,
            merge_clusters = TRUE,
            alpha = 0,
            lambda = NULL,
            seed = 2,
            return_obj = FALSE,
            mc.cores = mc.cores
        )
    })
})
# Out:
#    user  system elapsed
#   0.241   1.378   0.273

# %%
betas %>% str(1)
# Out:
# List of 2
#  $ 1:Formal class 'dgCMatrix' [package "Matrix"] with 6 slots
#  $ 2:Formal class 'dgCMatrix' [package "Matrix"] with 6 slots

# %%
class(betas[[1]])
# Out:
# [1] "dgCMatrix"
# attr(,"package")
# [1] "Matrix"

# %%
a <- betas[[1]] %>% data.matrix

# %%
t(a)
# Out:
#                              TRAC MS4A1
# threepfresh_AAACCTGAGCATCATC 0    4
# threepfresh_AAACCTGAGCTAACTC 0    1
# threepfresh_AAACCTGAGCTAGTGG 6    0
# threepfresh_AAACCTGCACATTAGC 6    0
# threepfresh_AAACCTGCACTGTTAG 0    0
# threepfresh_AAACCTGCATAGTAAG 0    0
# threepfresh_AAACCTGCATGAACCT 2    0
# threepfresh_AAACCTGGTAAGAGGA 4    0
# threepfresh_AAACCTGGTAGAAGGA 1    0
# threepfresh_AAACCTGGTCCAGTGC 7    0
# threepfresh_AAACCTGGTGTCTGAT 1    0
# threepfresh_AAACCTGGTTTGCATG 0    0
# threepfresh_AAACCTGGTTTGTTTC 2    0
# threepfresh_AAACCTGTCCGTTGCT 0    4
# threepfresh_AAACCTGTCCTGTAGA 2    0
# threepfresh_AAACCTGTCGCCAAAT 5    0
# threepfresh_AAACCTGTCGTGGACC 0    2
# threepfresh_AAACCTGTCTACCAGA 8    0
# threepfresh_AAACCTGTCTCAAGTG 2    0
# threepfresh_AAACCTGTCTCGCTTG 0    0
# threepfresh_AAACCTGTCTGCGGCA 3    0
# threepfresh_AAACGGGAGCCTCGTG 0    0
# threepfresh_AAACGGGAGGTGTGGT 5    0
# threepfresh_AAACGGGAGTACGATA 0    0
# threepfresh_AAACGGGCAAGTAGTA 0    3
# threepfresh_AAACGGGCACCTCGGA 0    2
# threepfresh_AAACGGGCACGAAACG 4    1
# threepfresh_AAACGGGCAGTAAGAT 0    4
# threepfresh_AAACGGGGTACAGTTC 1    0
# threepfresh_AAACGGGGTACCCAAT 0    4
# ⋮                            ⋮    ⋮
# fivePrime_TTTGGTTAGGATGCGT   0     0
# fivePrime_TTTGGTTCAAGGTGTG   1     0
# fivePrime_TTTGGTTCACAAGACG   1     0
# fivePrime_TTTGGTTCAGTGACAG   0     0
# fivePrime_TTTGGTTCATTTGCCC   0     2
# fivePrime_TTTGGTTGTAAGTGTA   0     1
# fivePrime_TTTGGTTGTCAAAGCG   2     0
# fivePrime_TTTGGTTGTCGAACAG   0     0
# fivePrime_TTTGGTTGTTATGCGT   1     0
# fivePrime_TTTGGTTGTTATTCTC   0     0
# fivePrime_TTTGGTTTCGTTGACA   0     0
# fivePrime_TTTGGTTTCTCACATT   0     0
# fivePrime_TTTGGTTTCTCGAGTA   1     0
# fivePrime_TTTGGTTTCTGCTTGC   1     0
# fivePrime_TTTGTCAAGAAACCTA   2     0
# fivePrime_TTTGTCAAGACCTAGG   0     0
# fivePrime_TTTGTCAAGAGCCCAA   0     0
# fivePrime_TTTGTCAAGGAATGGA   0     0
# fivePrime_TTTGTCAAGTCGAGTG   1     0
# fivePrime_TTTGTCACACATCCAA   0     0
# fivePrime_TTTGTCACAGCTGGCT   1     0
# fivePrime_TTTGTCACAGGTGGAT   0     0
# fivePrime_TTTGTCAGTCCGAAGA   1     0
# fivePrime_TTTGTCAGTTGATTGC   0     0
# fivePrime_TTTGTCATCACAAACC   0    14
# fivePrime_TTTGTCATCCACGTTC   0     0
# fivePrime_TTTGTCATCGCGTAGC   0     2
# fivePrime_TTTGTCATCTTAACCT   0     0
# fivePrime_TTTGTCATCTTACCGC   0     0
# fivePrime_TTTGTCATCTTGTTTG   0     0

# %%
l <- t(betas[[1]])
# Out:
# Error in t.default(betas[[1]]): argument is not a matrix
# Traceback:
#
# 1. t(betas[[1]])
# 2. t.default(betas[[1]])

# %%
obj$exprs_raw
# Out:
#   [[ suppressing 20792 column names ‘threepfresh_AAACCTGAGCATCATC’, ‘threepfresh_AAACCTGAGCTAACTC’, ‘threepfresh_AAACCTGAGCTAGTGG’ ... ]]
# 4 x 20792 sparse Matrix of class "dgCMatrix"
#
# TRAC  . . 6 6 . . 2 4 1 7 1 . 2 . 2 5 . 8 2 . 3 . 5 . . . 4 . 1 . 5 3 . 1 2 1 7
# MS4A1 4 1 . . . . . . . . . . . 4 . . 2 . . . . . . . 3 2 1 4 . 4 . . . . 1 . .
# CD3E  . . 2 2 . . 4 4 . 2 1 . 2 . 3 3 . 4 1 . . . 1 1 . . 3 . . . 2 1 . . . 1 1
# TRAC  2  . .  2 . . . . . . .  1 1 . 4 . 2 . 1 . . . . . . .  . . . 1 . . 1 . .
# MS4A1 .  . .  . . 2 . . . . .  . . . . . . . . . . . . . . . 11 . 4 . . . . 5 .
# CD3E  3 10 7 12 . . . . . 2 . 11 7 . 7 . 3 2 6 . . 7 . 5 . .  6 . . 5 . 7 1 4 .
# CD3D  2  2 2  7 . . . . . 4 .  5 6 . 1 . . 2 . . . 2 . 2 . .  2 . . 3 . 6 . 4 .
#
# TRAC  . . . 2 . . .  . . . 1 . 2 1 . . 2 . . . . .  7 . . . .  . . . . . . . .
# MS4A1 . . 8 . . . 3 11 . . . . . . . . . . . 5 . .  . . 4 . . 10 . . 6 . . 1 5
# CD3E  . . . 2 . 4 .  5 . . 4 . 3 4 6 1 5 . . . . . 10 . . . 5  . . . . 8 . . .
# CD3D  . . . 1 . 3 .  3 . . 3 . 1 1 . . . . . . . .  8 . . . .  . . . . 6 . . .
#
# TRAC  . 1 . . 1 1 . .  . 2 . . 1 .  1 . . . . . 1 . . . . . .  . . . 4 . . 1 .
# MS4A1 . . 1 . . . . .  . . . . 7 . 17 5 . . 4 . . 4 . 6 . . .  . . . . . . . .
# CD3E  4 5 . 4 6 6 3 . 14 9 8 5 . 5  . . . 7 . 5 6 . 8 . 2 . 3 11 . . 5 . . 4 7
# CD3D  4 2 . . 2 . 2 .  9 4 1 1 . 1  . . . 4 . . 2 . . . 2 . .  2 . . 3 . . 3 7
#
# TRAC  . . . .  . 2 . . . . . . . . 1 . . . . . . 1  3 . . . . .  1 . . . . 2 .
# MS4A1 . . 8 . 11 . . . . . . . . 5 9 . . . . 2 . .  . . . . . .  . . . . . . .
# CD3E  . . . .  . 8 . . . 3 . 4 5 . . 7 4 . 1 . 8 6 16 8 3 . 5 5 11 . . 9 4 5 .
# CD3D  . . . .  . 2 . . . . . 5 2 . . 1 1 . 1 . 2 2  8 1 4 . 1 3  3 . . 3 1 1 .
#
# TRAC  . 1 . . . . . . . . . . . 1 . . . . . . 1 . 3 2 1 . . . 3 . . . . . 2 . .
# MS4A1 . . . . 2 . 7 . . . . . 6 . . 3 . . . . . . . . . . 5 . . 6 . . . 3 . 7 .
# CD3E  . . 6 1 . . . . . 8 . . . 6 6 . . 7 2 5 3 9 5 5 7 . . . 4 . . . . . 6 . .
# CD3D  . . 5 . . . . . . 4 . . . 1 1 . . 5 1 1 2 2 5 1 3 . . . 5 . . 1 . . 2 . .
#
# TRAC  . 1 . . . .  . 3 . . . 1 . . 1  . . . . . . . . . .  . . . 1 . . . 2 . .
# MS4A1 . . . . . 2 20 . 5 . . . . . . 10 . . . . 3 3 . . .  . . . . 4 1 1 . . .
# CD3E  . 5 2 6 . .  . 2 . . . 7 . 1 1  . 5 . 9 . . . 3 2 . 10 . . 2 . 4 . 9 . 6
# CD3D  . 2 3 3 . .  . . . . . . . 1 1  . 3 . 1 . . . 3 2 .  3 . . 1 . 1 . 5 . 2
#
# TRAC  1 . . . . . . . . . . . 2  . . . 2 . . 1 2  .  . . . .  4 .  . . . 2 . .
# MS4A1 . 9 5 . . . . . . . . . .  . . . . . . . . 15  . . . .  . .  . . . . . .
# CD3D  3 1 . . . 2 . 7 . . 1 . 2 3 . . 3 1 . .  . . 2 . . . . . . . 2 . . 3 4 4
#
# TRAC  . . . . . . . . . 1 1 . . . . . . . .  . . . . . . . .  2  . . . . 1 . 1
# MS4A1 . . 5 . 1 . . . . . . . . . 3 5 8 . .  . . . . . . 5 . 18 10 . 8 . . . .
# CD3E  5 6 . 3 . 1 5 . . 3 2 . . . . . . 5 . 11 1 . . 6 . 1 .  .  . . . 2 6 . 8
# CD3D  2 4 . 1 . 2 3 . . 6 4 . . . . . . 4 .  3 4 1 . 5 . . .  .  . . . 1 2 . 2
#
# TRAC  1  . . . . . . .  2 .  . 3 . . . . . . 1 1 . 1 . . . 1 3 . . 1 1 . 2  . .
# MS4A1 . 12 . . . . . .  . . 15 . . . . . . . . . 3 . . . . . 1 . . . . . .  . .
# CD3E  4  . . . . . 4 . 11 1  . 6 7 9 3 4 8 5 8 7 . 4 1 . . . . . . 4 3 2 7 10 1
# CD3D  4  . . . . . 5 .  5 2  . 1 4 2 4 1 7 1 6 2 . . 5 . . 7 . . . 4 2 3 4  5 .
#
# TRAC  . . . 10 2  2 1 1 . 1 1 . . . . . . 1 .  2 2 3 . . . . . 1 . 1 . . 4 . .
# MS4A1 . . 5  . .  . . . 3 . . 5 . . . . . . .  . . . . . . . . . . . . . . 3 5
# CD3E  4 . .  9 8 10 8 5 . 4 4 . . . . 4 7 6 . 10 6 4 3 6 . 2 8 7 . 1 8 1 2 . .
# CD3D  2 . .  4 4  1 2 . . 5 . . . . . 1 2 1 .  3 3 2 2 3 . 1 6 6 . . 2 2 1 1 .
#
# TRAC  . . . 3  1 . 2 . . . .  . . . 3 . . . . . . . . . . . . 1 . . . . . .  .
# MS4A1 . . 1 . 20 . . . . . 8 13 . . . . . 4 . . . . . . . . . . . . . . . . 26
# CD3E  . 5 2 9  . . 5 . 9 . .  . . 4 5 . . . . 1 3 3 . 9 6 . 3 4 . 2 7 6 . 4  .
# CD3D  . 2 2 2  . . 4 . 1 . .  . . 1 7 . . . . . 2 . . 3 2 . 3 2 . 5 6 1 . 4  .
#
# TRAC  . 1 . . . . . . . . .  . . . 1 . 2 . .  1 . . . . . . . .  . 1 . . . . .
# MS4A1 . 3 . . 8 . . . . 7 5  . . . . . . . . 34 . 7 . . . . 1 4 10 . . . . . .
# CD3E  3 . . . . . 4 2 . . . 10 . 5 6 . 4 . 1  . . . 7 . . 4 . .  . 8 . 6 9 . 8
# CD3D  1 . . . . . 2 . . . .  4 . 4 4 . 4 . 1  . . . 1 . 1 1 . .  . 5 . 6 5 . 1
#
# TRAC   . .  . . . . . . . . . . .  . 2 . . . .  . . . 1 . 2 . . 1 . . . . . . .
# MS4A1 11 . 11 . . . . . . . . . .  . . . 2 . .  . . . . . . . . . . . . 1 . . .
# CD3E   . .  . 2 4 . . . . . . . 2 10 4 6 . . . 13 . . 4 . 7 5 . 9 1 8 3 7 1 2 .
# CD3D   . .  . 1 1 . . . . . . . .  1 . 2 . . .  5 . . . . 1 6 . 2 . 7 4 2 . . .
#
# TRAC  1 . . 1 . . . . . . . . 2 . 1 2 . 3  . . . . . .  . . . . . 1 . . . . . .
# MS4A1 . 4 . . . . . . . . 1 . . . . . . . 15 . . . 5 . 12 . . 6 . . 9 . . . . .
# CD3E  1 . . 8 . 6 . . . . . . 5 . 3 4 . 9  . . 3 4 . 4  . . . . . 4 2 6 6 . . .
# CD3D  2 . . 6 . 1 . . . . . . . . 3 3 . 3  . . 3 1 . 1  . . . . . 3 . 2 . . . .
#
# TRAC  . .  . . . . . 1 . . . . . . . . . 1 . . . . . . . 1 . . . . . . . 1 . .
# MS4A1 . . 18 . . . . . . 6 . . 1 . . . . . 7 . . 4 . . 1 . . . . . . . 1 . . 2
# CD3E  4 .  . . 5 . 2 6 6 . 3 5 . 4 . . . 6 . 8 4 . . 7 . 7 3 . . 4 . 4 . 7 3 .
# CD3D  2 .  . . 2 . 2 3 2 . 2 7 . 3 . . . 6 . 6 1 . . 4 . 2 . . . . . 4 . 2 . .
#
# TRAC  .  1 . . 1 . . . . . . 1  .  1 . 3 . . 1 . . . . . . . . . .  2  1 1 . .
# MS4A1 5 34 8 . . . . . 8 . . . 14  . . . 3 . . . . . . . 5 . . . .  .  . . . .
# CD3E  .  8 . . 2 . . . . 1 . 6  . 10 8 4 . 5 9 . . . 2 . . 3 . . . 10 13 9 6 4
# CD3D  .  3 . . . . . . . . . 4  .  1 . 4 . 2 1 . . . 3 . . 2 . . .  2  4 3 4 3
#
# TRAC  . . . . 2 . . . . . 1 .  . . 2 . 1 1 . .  . . 2 3 . .  . . . . . . 1 . .
# MS4A1 . . . . . . . . . . . 4 15 . . . . . . .  . . . . . . 15 2 . . . . . 9 .
# CD3E  . . 3 . 9 2 4 . 8 6 4 .  . . 4 . 2 7 . 5 10 . 2 6 3 .  . . 4 . . 3 5 . .
# CD3D  . . 1 . 2 1 1 . 6 1 2 .  . . 1 . 2 . . 2  4 . 1 3 . .  . . . . . . 3 . .
#
# TRAC  . . 1 . 5 . . 2 . . . . . . . . .  1 . . . .  . . . . . . 1 1 . 2 3 . . .
# MS4A1 . . . . . . . . . . . . . . . . .  . . . . .  . . . . . . . . . . . . 6 .
# CD3E  1 5 5 5 3 . . 6 . 3 . . . 9 . . . 12 5 . . . 14 . 8 . . 3 6 5 7 5 7 1 . .
# CD3D  1 3 3 3 4 . . 2 . 3 . . . 4 . . .  . 1 . . . 13 . 4 . . 5 3 2 3 5 6 2 . .
#
# TRAC  . 1 . . .  . . . . . . . . .  1 . . 1 1 .  8 . . . . . . . 2 . 2  3 . . .
# MS4A1 . . . . . 11 8 . 7 6 . . . . 11 . 1 . . .  . 1 . . . . 9 . . . 1  . . . .
# CD3E  . 2 . . .  . . . . . . . . .  . . . 3 8 1 11 . 5 . 5 . . 5 6 . 8 13 3 . .
# CD3D  . . . . .  . . . . . . . . .  . . . 1 3 1  . . 2 . 1 . . 2 2 . .  7 2 . .
#
# TRAC  .  3 . 1 . . . . . . . 1 . . . . . . . . . 2 1 . . . . . 1 3 1  1 . 2 . 1
# MS4A1 .  . . . . . . 7 . . . 1 . . . . . . . . . . . 7 . . . . . . .  . . . . .
# CD3E  3 11 . 7 . . 6 . 5 1 . 4 6 7 9 . 4 . 4 3 1 2 1 . . . 8 . 6 7 6  8 . 7 7 4
# CD3D  4 11 . 1 . . 4 . 5 . . 2 1 1 3 . 2 . . . . 3 3 . . . 2 . 2 1 4 14 . 1 1 2
#
# TRAC  .  . 1 1 .  . . . . 2 . . . 1 1 . 3 . . 2 .  . . . . . . 1 . . . 1 1 .  3
# MS4A1 . 10 . . .  . . . . . . 4 2 . . . 6 . . . .  . . . 1 . 7 . . . 7 . . .  .
# CD3E  .  . 8 7 . 10 6 . . 4 9 6 . 5 3 . . 2 5 5 . 10 . 7 . 4 . 5 . . . 5 1 . 12
# CD3D  .  . 4 5 .  3 2 . . 7 3 1 . 3 2 . . . 4 5 .  3 . 1 . 1 . 1 . . . 7 . .  2
#
# TRAC  . .  . . . . . 3 . 1 2 1 . . . . . 1 1 . . . 2 . 1 . . .  1 1 2 . . . 1 .
# MS4A1 . .  . . . . . . . . . . . . . . . . . . 2 1 . . . . . .  . . . . . . . .
# CD3E  . . 10 5 1 6 9 3 . 4 1 . . . 2 . . 7 5 3 . . 2 . 5 7 2 3 10 8 6 5 4 5 2 .
# CD3D  . .  6 4 1 4 3 3 . 2 5 3 . . 2 . . 7 3 . . . 1 . 3 2 3 6  1 1 2 6 2 3 . .
#
# TRAC  1 . 1 .  . . . . . .
# MS4A1 . . . . 14 . 2 . . .
# CD3E  9 7 2 .  . . . 5 . 6
# CD3D  4 2 1 .  . . . . . 3

# %%
betas
# Out:
# $`1`
# [1] "Error in t.default(Ycounts) : argument is not a matrix\n"
# attr(,"class")
# [1] "try-error"
# attr(,"condition")
# <simpleError in t.default(Ycounts): argument is not a matrix>
#
# $`2`
# [1] "Error in t.default(Ycounts) : argument is not a matrix\n"
# attr(,"class")
# [1] "try-error"
# attr(,"condition")
# <simpleError in t.default(Ycounts): argument is not a matrix>

# %%
betas
# Out:
# $`1`
# [1] "TRAC"  "MS4A1"
#
# $`2`
# [1] "CD3E" "CD3D"

# %%
# Run Crescendo
betas <- crescendo(
    Ycounts = obj$exprs_raw,
    meta_data = obj$meta_data,
    R = obj$R,
    genes_use = genes_use,
    prop = prop,
    min_cells = min_cells,
    batch_col = batch_col,
    id_col = id_col,
    constant_umi = TRUE,
    merge_clusters = TRUE,
    alpha = 0,
    lambda = NULL,
    seed = 2,
    return_obj = FALSE,
    mc.cores = mc.cores
)
# Out:
# Creating design matrix
#
# Getting discrete Harmony cluster
#
# Downsampling
#
# Estimating
#
# Marginalizing
#
# Matching

# %%
betas
# Out:
#    user  system elapsed
#   0.038   0.002   0.078
# $`1`
# [1] "TRAC"  "MS4A1"
#
# $`2`
# [1] "CD3E" "CD3D"

# %%
crescendo <- function(Ycounts, meta_data, R, genes_use = NULL, id_col = 'CellID', batch_col = 'batch',
                      prop = 1, min_cells = 50, constant_umi = TRUE, merge_clusters = TRUE,
                      lambda = NULL, alpha = 0, seed = 2, return_obj = FALSE, mc.cores = NULL, impute_reads = NULL){
    if(!(batch_col %in% colnames(meta_data))){
        stop('Provided column does not exist. Please input name of batch column')
    }
    if(!(id_col %in% colnames(meta_data))){
        stop('Provided column does not exist. Please input name of cell ID column')
    }
    
    if(is.null(mc.cores)){
        mc.cores <- max(1, detectCores() - 1)
    }
    meta_data$batch <- meta_data[[batch_col]]
    
    # Merge redundant clusters
    if(merge_clusters){
        R <- t(merge_redundant_clusters(R, 0.99))
        colnames(R) <- paste0('R', 1:ncol(R))
    } else{
        R <- t(R)
        colnames(R) <- paste0('R', 1:ncol(R))
    }
    
    # Use selected genes is applicable
    if(!is.null(genes_use)){
        Ycounts <- Ycounts[genes_use, , drop = FALSE]
    } else{
        genes_use <- rownames(Ycounts)
    }
    Ycounts <- t(Ycounts)
    
    offset <- log(meta_data$nUMI)
    if(constant_umi){
        final_reads <- log(rep(median(meta_data$nUMI), length(meta_data$nUMI)))
    } else{
        final_reads <- offset
    }
    if(!is.null(impute_reads)){
        final_reads <- impute_reads
    }
    
    message('Creating design matrix')
    design_full <- create_design_matrix(meta_data = meta_data, R = R, id_col = id_col)
    # Designate terms to keep (e.g. cluster terms)
    terms_keep <- grep('^R\\d+$|disease|(Intercept)', colnames(design_full), value = TRUE)
    # Designate terms to remove (e.g. interaction terms)
    terms_remove_crossed <- terms_remove_crossed <- grep(':batch', colnames(design_full), value = TRUE)
    
    # Downsampling
    if(prop != 1){
        message('Getting discrete Harmony cluster')
        meta_data$sampled_clus <- sample_harmony_clus(
            harmony_clusters = R,
            seed = seed,
            mc.cores = mc.cores
        )
        message('Downsampling')
        temp_meta <- downsample_batch_clus(
            meta_data = meta_data,
            id_col = id_col,
            batch_col = batch_col,
            clus_col = 'sampled_clus',
            min_cells = min_cells,
            prop = prop,
            seed = seed
        )

        temp_Ycounts <- Ycounts[temp_meta$idx, , drop = FALSE]
        temp_R <- R[temp_meta$idx, ]
        temp_offset <- offset[temp_meta$idx]
        temp_design <- design_full[temp_meta$idx, , drop = FALSE]
    } else{
        message('No downsampling selected')
        temp_meta <- meta_data
        temp_Ycounts <- Ycounts
        temp_R <- R
        temp_offset <- offset
        temp_design <- design_full
    }
    
    # Estimation
    message('Estimating')
    betas <- estimate_betas(
        Ycounts = temp_Ycounts,
        R = temp_R,
        design_full = temp_design,
        lambda = lambda,
        alpha = alpha,
        genes_use = genes_use,
        offset = temp_offset,
        mc.cores = mc.cores
    )

# %% [markdown]
# # Run Crescendo

# %%
# Run Crescendo
corr_counts <- crescendo(
    Ycounts = obj$exprs_raw,
    meta_data = obj$meta_data,
    R = obj$R,
    genes_use = genes_use,
    prop = prop,
    min_cells = min_cells,
    batch_col = batch_col,
    id_col = id_col,
    constant_umi = TRUE,
    merge_clusters = TRUE,
    alpha = 0,
    lambda = NULL,
    seed = 2,
    return_obj = FALSE,
    mc.cores = mc.cores
)
# Out:
# Creating design matrix
#
# Getting discrete Harmony cluster
#
# Downsampling
#
# Estimating
#
# Marginalizing
#
# Matching

# %%
corr_counts %>% str(1)
# Out:
#  int [1:20792, 1:2] 0 0 5 13 0 0 1 6 1 6 ...
#  - attr(*, "dimnames")=List of 2

# %% [markdown]
# # End
